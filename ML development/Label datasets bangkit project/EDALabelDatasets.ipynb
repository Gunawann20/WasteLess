# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %%
df = pd.read_excel("LabeledDatasets.xlsx")
df.head()
# Out:
#    Unnamed: 0  ayam-dagingT  ikan-seafoodT  tahu-tempe-telurT    sayurT  \
# 0           0      2.956622       0.263790          -0.804028 -0.164989
# 1           1      2.212821      -0.992702           0.592624 -0.025410
# 2           2      3.235548       0.310327           0.266738 -0.118462
# 3           3      2.305796      -0.527335          -0.431588  0.160695
# 4           4      3.049597      -0.015431          -1.316134 -0.583724
#
#     sambalT  nasi-mie-pastaT  sop-soto-baksoT  kue-rotiT  jajanan-pasarT  \
# 0  0.442037        -1.222774        -1.377233  -0.476528       -1.129483
# 1 -0.397436        -0.851014        -0.297525  -0.663209       -0.711423
# 2  0.022300         0.821907        -0.250581  -1.316594       -0.618521
# 3 -1.096997         0.914847        -1.142514   0.270197       -0.061108
# 4 -0.397436        -1.176304         0.923014   0.083516        0.124696
#
#    puding-jeliT  keripik-kerupukT  buah-minumanT  kmeans_12
# ...

# %% [markdown]
# ## Assessing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12341 entries, 0 to 12340
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12341 non-null  int64
#  1   ayam-dagingT       12341 non-null  float64
#  2   ikan-seafoodT      12341 non-null  float64
#  3   tahu-tempe-telurT  12341 non-null  float64
#  4   sayurT             12341 non-null  float64
#  5   sambalT            12341 non-null  float64
#  6   nasi-mie-pastaT    12341 non-null  float64
#  7   sop-soto-baksoT    12341 non-null  float64
#  8   kue-rotiT          12341 non-null  float64
#  9   jajanan-pasarT     12341 non-null  float64
#  10  puding-jeliT       12341 non-null  float64
#  11  keripik-kerupukT   12341 non-null  float64
#  12  buah-minumanT      12341 non-null  float64
#  13  kmeans_12          12341 non-null  int64
# dtypes: float64(12), int64(2)
# memory usage: 1.3 MB

# %% [markdown]
# ## EDA

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0  ayam-dagingT  ikan-seafoodT  tahu-tempe-telurT  \
# count  12341.000000  1.234100e+04   1.234100e+04       1.234100e+04
# mean    6170.000000 -3.649315e-16  -2.121937e-15       1.815616e-16
# std     3562.684171  1.000041e+00   1.000041e+00       1.000041e+00
# min        0.000000 -1.366722e+00  -1.364996e+00      -1.362689e+00
# 25%     3085.000000 -7.623833e-01  -7.600182e-01      -7.574731e-01
# 50%     6170.000000 -1.115574e-01  -1.085040e-01      -1.057023e-01
# 75%     9255.000000  5.392686e-01   4.964735e-01       4.995134e-01
# max    12340.000000  3.235548e+00   3.242140e+00       3.246262e+00
#
#              sayurT       sambalT  nasi-mie-pastaT  sop-soto-baksoT  \
# count  1.234100e+04  1.234100e+04     1.234100e+04     1.234100e+04
# mean  -1.624015e-15 -6.772172e-16    -8.994597e-16     1.332902e-15
# std    1.000041e+00  1.000041e+00     1.000041e+00     1.000041e+00
# min   -1.374669e+00 -1.376821e+00    -1.362184e+00    -1.377233e+00
# ...

# %%
Agg_df = df.groupby(by="kmeans_12").agg({
    'ayam-dagingT' : 'mean' ,
    'ikan-seafoodT' : 'mean' , 
    'tahu-tempe-telurT': 'mean', 
    'sayurT': 'mean',
    'sambalT': 'mean',
    'nasi-mie-pastaT': 'mean',
    'sop-soto-baksoT': 'mean',
    'kue-rotiT': 'mean',
    'jajanan-pasarT': 'mean',
    'puding-jeliT': 'mean',
    'keripik-kerupukT': 'mean',
    'buah-minumanT': 'mean'
})

# %%
Agg_df
# Out:
#            ayam-dagingT  ikan-seafoodT  tahu-tempe-telurT    sayurT   sambalT  \
# kmeans_12
# 0             -0.222087      -0.229751          -0.227462 -0.222809 -0.237490
# 1              2.527506      -0.230122          -0.210579 -0.228573 -0.244106
# 2             -0.198905      -0.233208          -0.235041 -0.236492 -0.228314
# 3             -0.207133      -0.232493          -0.278249 -0.233174 -0.213962
# 4             -0.276098      -0.206552           2.548540 -0.219881 -0.214661
# 5             -0.239642      -0.215896          -0.221602 -0.239356 -0.194114
# 6             -0.231143      -0.234725          -0.176209  2.538502 -0.199705
# 7             -0.206855      -0.211852          -0.235554 -0.213327 -0.223979
# 8             -0.228543      -0.248812          -0.238996 -0.229967  2.544493
# 9             -0.201978      -0.200927          -0.197371 -0.233453 -0.230222
# 10            -0.225895      -0.217989          -0.243042 -0.191017 -0.222301
# ...

# %%
Agg_df.plot.bar(figsize=(10,10))
plt.show(block=True);

# %% [markdown]
# Label
# 0 = jajanan-pasar
# 1 = ayam-daging
# 2 = buah-minuman
# 3 = puding-jeli
# 4 = tahu-tempe-telur
# 5 = kue-roti
# 6 = sayur
# 7 = keripik-kerupuk
# 8 = sambal
# 9 = sop-soto-bakso
# 10 = nasi-mie-pasta
# 11 = ikan-seafood
